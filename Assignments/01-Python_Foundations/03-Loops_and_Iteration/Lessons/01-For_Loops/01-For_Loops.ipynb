# %% [markdown]
# # 📘 01 - For Loops
#
# Learn how to use `for` loops to iterate over sequences.

# %% [markdown]
# ## ✅ Learning Goals
# - Use `for` with lists, strings, and `range()`
# - Understand loop variables and block structure

# %%
# 🔁 Loop over a list
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
# 🔁 Loop over characters in a string
word = 'hello'
for char in word:
    print(char)

# %%
# 🔁 Using range()
for i in range(5):
    print(i)

# %%
# ➕ Loop with math
for i in range(1, 6):
    print(f'{i} squared is', i ** 2)

# %% [markdown]
# ### ✏️ Your Turn
# Loop over a list of 3 favorite movies and print them in all caps.

# %%
movies = ["Interstellar", "Spider-Man", "The Dark Knight"]

for movie in movies:
    print(movie.upper())

# %%
movies = ['THE GREAT GATSBY', 'THE NOTEBOOK', 'REMINDERS OF HIM']

for i in movies:
    print (i)
# Out:
# THE GREAT GATSBY
# THE NOTEBOOK
# REMINDERS OF HIM
